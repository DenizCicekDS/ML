# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('example.csv')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df1 = pd.read_csv('sample.csv')

# %%
df1
# Out:
#     x   w   y   z
# 0   1   2   3   4
# 1   5   6   7   8
# 2   9  10  11  12
# 3  13  14  15  16

# %%
df1.to_csv('sample_2.csv')

# %%
pd.read_csv('sample_2.csv', index_col=0)
# Out:
#     x   w   y   z
# 0   1   2   3   4
# 1   5   6   7   8
# 2   9  10  11  12
# 3  13  14  15  16

# %%
pd.read_csv('titanic.csv')
# Out:
#                         PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund           Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings          Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen        Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle         Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen            Mr. William Henry\tmale\t35\t0\t0\t373450\t8....
# ...                                                                    ...
# 152\t1\t1\tPears          Mrs. Thomas (Edith Wearne)\tfemale\t22\t1\t0\...
# 153\t0\t3\tMeo            Mr. Alfonzo\tmale\t55.5\t0\t0\tA.5. 11206\t8....
# 154\t0\t3\tvan Billiard   Mr. Austin Blyler\tmale\t40.5\t0\t2\tA/5. 851...
# 155\t0\t3\tOlsen          Mr. Ole Martin\tmale\t\t0\t0\tFa 265302\t7.31...
# 156\t0\t1\tWilliams       Mr. Charles Duane\tmale\t51\t0\t1\tPC 17597\t...
#
# [156 rows x 1 columns]

# %%
titanic = pd.read_csv('titanic.csv', sep='\t')

# %%
titanic.to_json('json_titanic.json')

# %%
ornek = pd.read_csv('ornekcsv.csv', sep=';')

# %%
ornek.to_csv('ornekcsv_2.csv', index = False)

# %%
pd.read_csv('ornekcsv_2.csv')
# Out:
#       a    b     c
# 0    78   12   1.0
# 1    78   12   2.0
# 2    78  324   3.0
# 3     7    2   4.0
# 4    88   23   5.0
# 5     6    2   NaN
# 6    56   11   6.0
# 7     7   12   7.0
# 8    56   21   7.0
# 9   346    2   8.0
# 10    5    1   8.0
# 11  456   21   8.0
# 12    3   12  88.0

# %%
df = pd.read_excel("Excel_Sample.xlsx")

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df1 = pd.read_excel("Excel_Sample.xlsx")
df1
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_excel('ornekx.xlsx')
# Out:
#         a      b     c
# 0    78.0   12.0   1.0
# 1    78.0   12.0   2.0
# 2    78.0  324.0   3.0
# 3     7.0    2.0   4.0
# 4     NaN   23.0   5.0
# 5     6.0    2.0   NaN
# 6     NaN   11.0   6.0
# 7     7.0   12.0   7.0
# 8    56.0   21.0   7.0
# 9   346.0    NaN   8.0
# 10    5.0    1.0   8.0
# 11  456.0   21.0   8.0
# 12    3.0   12.0  88.0

# %%
df.to_excel('Excel-Sample_1.xlsx', sheet_name='Sheet-1', index = False)

# %%
df = pd.read_html("https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/")

# %%
df
# Out:
# [                         Bank NameBank           CityCity StateSt  CertCert  \
#  0                    Almena State Bank             Almena      KS     15426
#  1           First City Bank of Florida  Fort Walton Beach      FL     16748
#  2                 The First State Bank      Barboursville      WV     14361
#  3                   Ericson State Bank            Ericson      NE     18265
#  4     City National Bank of New Jersey             Newark      NJ     21111
#  ..                                 ...                ...     ...       ...
#  558                 Superior Bank, FSB           Hinsdale      IL     32646
#  559                Malta National Bank              Malta      OH      6629
#  560    First Alliance Bank & Trust Co.         Manchester      NH     34264
#  561  National State Bank of Metropolis         Metropolis      IL      3815
#  562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
df[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
ri = pd.read_csv('police.csv')
# Out:
# C:\Users\zende\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (8,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
ri
# Out:
#                    id state   stop_date stop_time location_raw  county_name  \
# 0       RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2       RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3       RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509676       RI-NA-06    RI         NaN       NaN      Zone NA          NaN
# 509677       RI-NA-07    RI         NaN       NaN      Zone NA          NaN
# 509678       RI-NA-08    RI         NaN       NaN      Zone NA          NaN
# 509679       RI-NA-09    RI         NaN       NaN      Zone NA          NaN
# 509680       RI-NA-10    RI         NaN       NaN      Zone NA          NaN
#
# ...

# %%
ri.head()
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2  RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 2          NaN                    NaN                 0           NaN  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# ...

# %%
ri.isnull()
# Out:
#            id  state  stop_date  stop_time  location_raw  county_name  \
# 0       False  False      False      False         False         True
# 1       False  False      False      False         False         True
# 2       False  False      False      False         False         True
# 3       False  False      False      False         False         True
# 4       False  False      False      False         False         True
# ...       ...    ...        ...        ...           ...          ...
# 509676  False  False       True       True         False         True
# 509677  False  False       True       True         False         True
# 509678  False  False       True       True         False         True
# 509679  False  False       True       True         False         True
# 509680  False  False       True       True         False         True
#
#         county_fips  fine_grained_location  police_department  driver_gender  \
# ...

# %%
ri.isnull().sum()
# Out:
# id                            0
# state                         0
# stop_date                    10
# stop_time                    10
# location_raw                  0
# county_name              509681
# county_fips              509681
# fine_grained_location    509681
# police_department            10
# driver_gender             29097
# driver_age_raw            29049
# driver_age                30695
# driver_race_raw           29073
# driver_race               29073
# violation_raw             29073
# violation                 29073
# search_conducted             10
# search_type_raw          491919
# search_type              491919
# contraband_found              0
# stop_outcome              29073
# is_arrested               29073
# stop_duration             29073
# out_of_state              29881
# drugs_related_stop            0
# district                      0
# dtype: int64

# %%
ri.drop('county_name', axis=1)
# Out:
#                    id state   stop_date stop_time location_raw  county_fips  \
# 0       RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 2       RI-2005-00003    RI  2005-01-04     11:30      Zone X1          NaN
# 3       RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509676       RI-NA-06    RI         NaN       NaN      Zone NA          NaN
# 509677       RI-NA-07    RI         NaN       NaN      Zone NA          NaN
# 509678       RI-NA-08    RI         NaN       NaN      Zone NA          NaN
# 509679       RI-NA-09    RI         NaN       NaN      Zone NA          NaN
# 509680       RI-NA-10    RI         NaN       NaN      Zone NA          NaN
#
# ...

# %%
ri.drop('state', axis=1)
# Out:
#                    id   stop_date stop_time location_raw  county_name  \
# 0       RI-2005-00001  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002  2005-01-02     20:30      Zone X4          NaN
# 2       RI-2005-00003  2005-01-04     11:30      Zone X1          NaN
# 3       RI-2005-00004  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005  2005-01-06     01:30      Zone X4          NaN
# ...               ...         ...       ...          ...          ...
# 509676       RI-NA-06         NaN       NaN      Zone NA          NaN
# 509677       RI-NA-07         NaN       NaN      Zone NA          NaN
# 509678       RI-NA-08         NaN       NaN      Zone NA          NaN
# 509679       RI-NA-09         NaN       NaN      Zone NA          NaN
# 509680       RI-NA-10         NaN       NaN      Zone NA          NaN
#
#         county_fips  fine_grained_location police_department driver_gender  \
# ...

# %%
ri.isnull().sum()
# Out:
# id                            0
# state                         0
# stop_date                    10
# stop_time                    10
# location_raw                  0
# county_name              509681
# county_fips              509681
# fine_grained_location    509681
# police_department            10
# driver_gender             29097
# driver_age_raw            29049
# driver_age                30695
# driver_race_raw           29073
# driver_race               29073
# violation_raw             29073
# violation                 29073
# search_conducted             10
# search_type_raw          491919
# search_type              491919
# contraband_found              0
# stop_outcome              29073
# is_arrested               29073
# stop_duration             29073
# out_of_state              29881
# drugs_related_stop            0
# district                      0
# dtype: int64

# %%
ri.dropna(subset = ['driver_gender'], inplace = True)

# %%
ri.isnull().sum()
# Out:
# id                            0
# state                         0
# stop_date                     0
# stop_time                     0
# location_raw                  0
# county_name              480584
# county_fips              480584
# fine_grained_location    480584
# police_department             0
# driver_gender                 0
# driver_age_raw                1
# driver_age                 1638
# driver_race_raw               0
# driver_race                   0
# violation_raw                 0
# violation                     0
# search_conducted              0
# search_type_raw          462822
# search_type              462822
# contraband_found              0
# stop_outcome                  0
# is_arrested                   0
# stop_duration                 0
# out_of_state                808
# drugs_related_stop            0
# district                      0
# dtype: int64

# %%
ri.shape
# Out:
# (480584, 26)

# %%
ri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480584 entries, 0 to 509670
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     480584 non-null  object
#  1   state                  480584 non-null  object
#  2   stop_date              480584 non-null  object
#  3   stop_time              480584 non-null  object
#  4   location_raw           480584 non-null  object
#  5   county_name            0 non-null       float64
#  6   county_fips            0 non-null       float64
#  7   fine_grained_location  0 non-null       float64
#  8   police_department      480584 non-null  object
#  9   driver_gender          480584 non-null  object
#  10  driver_age_raw         480583 non-null  float64
#  11  driver_age             478946 non-null  float64
#  12  driver_race_raw        480584 non-null  object
#  13  driver_race            480584 non-null  object
# ...

# %%
ri.dtypes
# Out:
# id                        object
# state                     object
# stop_date                 object
# stop_time                 object
# location_raw              object
# county_name              float64
# county_fips              float64
# fine_grained_location    float64
# police_department         object
# driver_gender             object
# driver_age_raw           float64
# driver_age               float64
# driver_race_raw           object
# driver_race               object
# violation_raw             object
# violation                 object
# search_conducted          object
# search_type_raw           object
# search_type               object
# contraband_found            bool
# stop_outcome              object
# is_arrested               object
# stop_duration             object
# out_of_state              object
# drugs_related_stop          bool
# district                  object
# dtype: object

# %%
ri.is_arrested.head()
# Out:
# 0    False
# 1    False
# 3    False
# 4    False
# 5    False
# Name: is_arrested, dtype: object

# %%
type(ri.is_arrested.values[0])
# Out:
# bool

# %%
ri['is_arrested'] = ri.is_arrested.astype('bool')

# %%
ri['is_arrested']
# Out:
# 0         False
# 1         False
# 3         False
# 4         False
# 5         False
#           ...
# 509666    False
# 509667    False
# 509668    False
# 509669    False
# 509670    False
# Name: is_arrested, Length: 480584, dtype: bool

# %%
ri.head()
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# 5  RI-2005-00006    RI  2005-01-12     08:05      Zone X1          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
# 5          NaN                    NaN                 0             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# ...

# %%
combined = ri.stop_date.str.cat(ri.stop_time, sep = " ")

# %%
combined
# Out:
# 0         2005-01-02 01:55
# 1         2005-01-02 20:30
# 3         2005-01-04 12:55
# 4         2005-01-06 01:30
# 5         2005-01-12 08:05
#                 ...
# 509666    2015-12-31 22:46
# 509667    2015-12-31 22:47
# 509668    2015-12-31 23:08
# 509669    2015-12-31 23:44
# 509670    2015-12-31 23:48
# Name: stop_date, Length: 480584, dtype: object

# %%
ri.head()
# Out:
#               id state   stop_date stop_time location_raw  county_name  \
# 0  RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1  RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 3  RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4  RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# 5  RI-2005-00006    RI  2005-01-12     08:05      Zone X1          NaN
#
#    county_fips  fine_grained_location police_department driver_gender  ...  \
# 0          NaN                    NaN               600             M  ...
# 1          NaN                    NaN               500             M  ...
# 3          NaN                    NaN               500             M  ...
# 4          NaN                    NaN               500             M  ...
# 5          NaN                    NaN                 0             M  ...
#
#    search_conducted  search_type_raw search_type contraband_found  \
# ...

# %%
ri["stop_datetime"] = pd.to_datetime(combined)

# %%
ri
# Out:
#                    id state   stop_date stop_time location_raw  county_name  \
# 0       RI-2005-00001    RI  2005-01-02     01:55      Zone K1          NaN
# 1       RI-2005-00002    RI  2005-01-02     20:30      Zone X4          NaN
# 3       RI-2005-00004    RI  2005-01-04     12:55      Zone X4          NaN
# 4       RI-2005-00005    RI  2005-01-06     01:30      Zone X4          NaN
# 5       RI-2005-00006    RI  2005-01-12     08:05      Zone X1          NaN
# ...               ...   ...         ...       ...          ...          ...
# 509666  RI-2015-47061    RI  2015-12-31     22:46      Zone X1          NaN
# 509667  RI-2015-47062    RI  2015-12-31     22:47      Zone X4          NaN
# 509668  RI-2015-47063    RI  2015-12-31     23:08      Zone X3          NaN
# 509669  RI-2015-47064    RI  2015-12-31     23:44      Zone K2          NaN
# 509670  RI-2015-47065    RI  2015-12-31     23:48      Zone K3          NaN
#
# ...

# %%
ri.drop(['stop_date', 'stop_time'], axis='columns', inplace=True)

# %%
ri.set_index("stop_datetime", inplace = True)

# %%
ri.head()
# Out:
#                                 id state location_raw  county_name  \
# stop_datetime
# 2005-01-02 01:55:00  RI-2005-00001    RI      Zone K1          NaN
# 2005-01-02 20:30:00  RI-2005-00002    RI      Zone X4          NaN
# 2005-01-04 12:55:00  RI-2005-00004    RI      Zone X4          NaN
# 2005-01-06 01:30:00  RI-2005-00005    RI      Zone X4          NaN
# 2005-01-12 08:05:00  RI-2005-00006    RI      Zone X1          NaN
#
#                      county_fips  fine_grained_location police_department  \
# stop_datetime
# 2005-01-02 01:55:00          NaN                    NaN               600
# 2005-01-02 20:30:00          NaN                    NaN               500
# 2005-01-04 12:55:00          NaN                    NaN               500
# 2005-01-06 01:30:00          NaN                    NaN               500
# 2005-01-12 08:05:00          NaN                    NaN                 0
#
#                     driver_gender  driver_age_raw  driver_age  ...  \
# ...

# %%
ri.shape
# Out:
# (480584, 24)

# %%
ri.columns
# Out:
# Index(['id', 'state', 'location_raw', 'county_name', 'county_fips',
#        'fine_grained_location', 'police_department', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race_raw', 'driver_race',
#        'violation_raw', 'violation', 'search_conducted', 'search_type_raw',
#        'search_type', 'contraband_found', 'stop_outcome', 'is_arrested',
#        'stop_duration', 'out_of_state', 'drugs_related_stop', 'district'],
#       dtype='object')
